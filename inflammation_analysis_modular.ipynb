# %%
import glob

from processing import visualize, detect_problems

filenames = sorted(glob.glob('data/inflammation*.csv'))
filenames = filenames[0:3]

for filename in filenames:
    detect_problems(filename)
    visualize(filename)
# Out:
# Suspicious looking maxima
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       8 for filename in filenames:
#       9     detect_problems(filename)
# ---> 10     visualize(filename)
#
# File ~\Desktop\swc-python\processing.py:28, in visualize(filename)
#      25 axes2.plot(np.max(data, axis=0))
#      26 axes3.plot(np.min(data, axis=0))
# ---> 28 plt.savefig(f'inflammation{index}.png')
#      29 plt.show()
#
# NameError: name 'index' is not defined
